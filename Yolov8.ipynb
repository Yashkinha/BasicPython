# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashkinha/BasicPython/blob/main/Yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.2/699.2 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
import locale
locale.getdefaultlocale()
('en_US', locale.getpreferredencoding())
# Out:
# ('en_US', 'UTF-8')

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 500, in entrypoint
#     check_dict_alignment(full_args_dict, overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 308, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'tast' is not a valid YOLO argument. Similar arguments are i.e. ['task=detect', 'translate=0.1'].
#
#     Arguments received: ['yolo', 'tast=detect', 'mode=predict', 'model=yolov8l.pt', 'conf=0.25', 'source=https://ultralytics.com/images/bus.jpg']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose', 'obb')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo task=detect mode=train model=yolov8l.pt source='/content/drive/MyDrive/Construction Site Safety.v28-yolov5s.yolov8/data.yaml' epochs=50 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 223MB/s]
# WARNING ⚠️ 'data' is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
